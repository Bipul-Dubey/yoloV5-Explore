# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# D:\yoloV5explore\preTrainedDatasets\yolov5

# %%
#pip install -r requirements.txt

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5  v7.0-196-gacdf73b Python-3.11.1 torch-2.0.1+cpu CPU
# Setup complete  (8 CPUs, 7.7 GB RAM, 7.5/100.6 GB disk)

# %% [markdown]
# ## pedict

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ../dataTopredict/traffic.png --project ../predictedOutput/ --name output
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING  'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
display.Image(filename='../predictedOutput/output/traffic.png', width=600)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source 0
# Out:
# ^C
