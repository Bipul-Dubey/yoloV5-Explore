# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5/
# Out:
# /home/xs329-bipdub/yoloV5-Explore/customDataTraining/yolov5

# %%
pip install -r requirements.txt

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.8.10 torch-2.0.1+cu117 CPU
# Setup complete ✅ (6 CPUs, 15.4 GB RAM, 91.3/233.2 GB disk)

# %% [markdown]
# ## train custom data

# %%
# !python3 train.py --img 640 --epochs 50 --data custom_data.yaml
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.8.10 torch-2.0.1+cu117 CPU
#
# ...

# %%
# !python3 detect.py --data custom_data.yaml --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../dataTopredict/person3.jpg --project ../predictedOutput/ --name output
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../dataTopredict/person3.jpg, data=custom_data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../predictedOutput/, name=output, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.8.10 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/xs329-bipdub/yoloV5-Explore/customDataTraining/dataTopredict/person3.jpg: 448x640 1 Person, 70.8ms
# Speed: 0.5ms pre-process, 70.8ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ../predictedOutput/output3

# %%
display.Image(filename='../predictedOutput/output3/person3.jpg', width=600)
